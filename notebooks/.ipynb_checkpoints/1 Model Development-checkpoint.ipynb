# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

# %%
import pandas as pd

# %%
songs = pd.read_csv('..//data/my_songs_with_labels.csv', index_col = [0])

# %% [markdown]
# ## Model development

# %%
songs_features = ['danceability', 'energy',
                  'mode', 'acousticness', 'instrumentalness',
                  'liveness', 'valence', 
                  'loudness_norm', 'tempo_norm', 'key_norm', 
                  'time_signature_norm']

# %%
models = []

models.append(("LogisticRegression",LogisticRegression(solver = 'lbfgs',multi_class='auto', max_iter = 42000, random_state = 42)))
models.append(("LinearSVC",LinearSVC(max_iter = 42000, random_state = 42)))
models.append(("DecisionTree",DecisionTreeClassifier()))
models.append(("RandomForest",RandomForestClassifier(n_estimators = 100)))
models.append(("MLPClassifier",MLPClassifier(solver='lbfgs', max_iter = 9000, random_state=42)))

# %%
X = songs[songs_features]
y = songs.iloc[:,-1]    #labels

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
results = []
names = []

for name, model in models:
    result = cross_val_score(model, X_train, y_train,  cv = 5)
    names.append(name)
    results.append(result)

for i in range(len(names)):
    print(names[i],results[i].mean())
# Out:
# LogisticRegression 0.9652173913043478
# LinearSVC 0.9855072463768115
# DecisionTree 0.9391304347826088
# RandomForest 0.9594202898550724
# MLPClassifier 0.9855072463768115

# %%
model = LogisticRegression(solver = 'lbfgs',multi_class='auto', max_iter = 10000, random_state = 99)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000, random_state=99)

# %%
y_pred = model.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[33,  0,  0,  0,  2],
#        [ 0, 22,  0,  1,  0],
#        [ 0,  0, 22,  0,  1],
#        [ 0,  0,  0, 28,  0],
#        [ 0,  0,  0,  0, 40]])

# %%
model2 = MLPClassifier(solver='lbfgs', max_iter = 9000, random_state=42)
model2.fit(X_train, y_train)
# Out:
# MLPClassifier(max_iter=9000, random_state=42, solver='lbfgs')

# %%
y_pred2 = model2.predict(X_test)
confusion_matrix(y_test, y_pred2)
# Out:
# array([[35,  0,  0,  0,  0],
#        [ 0, 21,  0,  2,  0],
#        [ 0,  0, 23,  0,  0],
#        [ 0,  0,  0, 28,  0],
#        [ 1,  0,  0,  0, 39]])

# %% [markdown]
# Test on realout of sample data

# %%
import config

# %%
client_id = config.client_id
client_secret = config.client_secret

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util

import sys
sys.path.insert(0, '/Users/alanlau/Documents/Projects/music_analyzer/data')

import scraper

# %%
df_test = scraper.datascrape('spotify', '37i9dQZF1DX3lmnsqvYpgD', sp)

# %%
df_test
# Out:
#                                     title    first_artist  \
# 0                         (一個男人) 一個女人 和浴室       Louis Koo
# 1                                     彌敦道        Ken Hung
# 2                   但願人長久 - 劇集 "跳躍生命線" 插曲            HANA
# 3                                    老少平安      Pakho Chau
# 4                                   困獸‧28        Juno Mak
# 5                                    海枯石爛         Kary Ng
# 6                    Tracey (電影 "翠絲" 主題曲)    Panther Chan
# 7                                  掉進海的眼淚       Kaho Hung
# 8                                     永生花             曾樂彤
# 9                                      狂迷             鄧思朗
# 10                                    別氹我          JC 陳泳彤
# 11                                  後來沒有你             蔚雨芯
# 12                                教我這麼愛下去        Andy Hui
# 13                 陪著你走 - 劇集 "不懂撒嬌的女人" 插曲       Kayee Tam
# 14                                   可一可再      Eason Chan
# 15                 為何你要背叛我 - 劇集 "再創世紀" 插曲        Jinny Ng
# 16                                  閃亮的青春             梁釗峰
# 17                       班門大叔 (feat. 徐隆威)     Vivian Chan
# 18                                   神不守舍        Kwan Gor
# 19                                     星光      Fred Cheng
# 20                                   甜言騙局       Kayee Tam
# 21  Superman - Xtra Soft Acoustic Version             AGA
# 22                  盡力呼吸 (ViuTV 身後事務所主題曲)       Yoyo Sham
# 23                                   人間鬍子         Gin Lee
# 24                                   若無其事             謝文欣
# 25                               停半分鐘聽一闋歌      Alfred Hui
# 26                                     孤雛             AGA
# 27                        近在千里 (feat. 衛蘭)      Pakho Chau
# 28                                一個女人和浴室         Kay Tse
# 29                            假使世界原來不像你預期  Charmaine Fong
# 30                               青春、戀愛和意外             曾樂彤
# 31             你會有一天學會面對 (電視劇《身後事務所》 主題曲)      RubberBand
# 32                                    安全感              JW
# 33                                   獨一無二             AGA
# 34                                     18            At17
# 35                               獻醜 (合唱版)        Ken Hung
# 36                                     痛醒      Alfred Hui
# 37                                  勇悍‧17        Juno Mak
# 38                                    小故事              JW
# 39                                   抱夢而活         Gin Lee
# 40                                      忍         Mag Lam
# 41                自由 - “鑽石人生” Demo Lyrics             AGA
# 42                                     傳聞      Pakho Chau
# 43                                  人妻的偽術         Kay Tse
# 44                              愛情是一種法國甜品        Eman Lam
# 45                                   男人背後      Pakho Chau
# 46                                   櫻花樹下     Hins Cheung
# 47                                  永遠愛著你      Vivian Lai
# 48                                     橡筋       Endy Chow
# 49                                     空姐         Gin Lee
#
#                              all_artists                      id  \
# 0                   [Louis Koo, Kay Tse]  5NvsRbIoMFMqBAVFHn1f3X
# 1                             [Ken Hung]  2HRMHz6NgX2p2BehbjAxN4
# 2                                 [HANA]  2cZ78DPU09gFPZZdAjykGP
# 3                           [Pakho Chau]  0BWHYaG1cdHp1uVDH0BiDp
# 4                             [Juno Mak]  5xe1gdm6N93e3FUiXZ56dZ
# 5                              [Kary Ng]  3sPjiPdvxAPqIqqMjwCThw
# 6                         [Panther Chan]  4lmOXmwygGpCEwXqXryY6B
# 7                            [Kaho Hung]  14E27fUMTIrhQtOxMWP0py
# 8                                  [曾樂彤]  0GnO5L1HgmcQlFaRbmdfVX
# 9                                  [鄧思朗]  6XO1iXHKTLkk231Q3RfYkT
# 10                              [JC 陳泳彤]  20GS43c9bGvL7UEb4lJeme
# 11                                 [蔚雨芯]  6CImTez90g714WjQxYmBJ2
# 12                            [Andy Hui]  0vKBUATOetUAnDJBlZ5KVK
# 13                           [Kayee Tam]  3HMesevL5DK01uEpHrn9IO
# 49         0.690   0.376    6    -8.444     1        0.9330          0.000006
#
#     liveness  valence    tempo  duration_ms  time_signature
# 0     0.1390    0.467  111.810       300000               4
# 1     0.1170    0.416  112.916       245523               4
# 2     0.1070    0.232  183.357       240547               4
# 3     0.0861    0.567  144.109       208923               4
# 4     0.0837    0.366  151.762       267632               4
# 5     0.1040    0.190  141.936       257000               4
# 6     0.1110    0.412  144.077       268000               4
# 7     0.1930    0.355  123.955       239248               4
# 8     0.1140    0.539  118.988       228692               4
# 9     0.1070    0.576  112.013       246828               4
# 10    0.1060    0.417  123.015       265366               4
# 11    0.1380    0.323  136.075       228294               4
# 12    0.1120    0.506  142.869       267692               4
# 13    0.0754    0.216  101.015       211601               4
# 14    0.0904    0.539  159.940       284618               4
# 15    0.2040    0.582  116.955       274428               4
# 16    0.1060    0.286   73.956       278000               4
# 17    0.6240    0.363  153.011       270752               4
# 18    0.1090    0.418  122.104       215260               4
# 19    0.0963    0.412  150.054       290400               4
# 20    0.1710    0.384   92.570       234522               4
# 21    0.1110    0.260   76.057       247775               4
# 22    0.0836    0.104  138.608       236727               4
# 23    0.0963    0.074  149.668       248799               4
# 24    0.0967    0.243  130.083       200752               1
# 25    0.1140    0.342  135.984       258959               4
# 26    0.1320    0.478  157.864       293331               4
# 27    0.1150    0.358  118.373       281707               4
# 28    0.1330    0.537  113.977       283421               4
# 29    0.1140    0.347  139.821       267531               4
# 30    0.1510    0.403  128.965       250242               4
# 31    0.1080    0.386   89.010       286133               4
# 32    0.1740    0.508  133.770       217752               4
# 33    0.1630    0.343  143.421       320220               4
# 34    0.1110    0.199  183.455       222000               4
# 35    0.1280    0.374  129.876       251077               4
# 36    0.2640    0.425  124.987       236896               4
# 37    0.1070    0.501  135.889       286822               4
# 38    0.1230    0.428  137.641       210860               4
# 39    0.1270    0.253  128.058       240540               4
# 40    0.1050    0.739  128.694       248652               4
# 41    0.0828    0.228  126.855       241597               4
# 42    0.0998    0.423   96.161       247018               4
# 43    0.1360    0.589  116.017       277759               4
# 44    0.1030    0.224  132.714       237820               4
# 45    0.1150    0.340  127.948       254515               4
# 46    0.1970    0.300  143.680       249987               4
# 47    0.0860    0.253  127.980       350260               4
# 48    0.1330    0.221   73.956       280766               4
# 49    0.1170    0.159  136.046       225882               4

# %%
music_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 
                  'acousticness', 'instrumentalness', 'liveness', 
                  'valence', 'duration_ms', 'time_signature']

# %%
from sklearn import preprocessing

# %%
# Feature: loudness
loudness = df_test[['loudness']]
min_max_scalar = preprocessing.MinMaxScaler()

loudness = min_max_scalar.fit_transform(loudness)
df_test['loudness_norm'] = loudness

# Feature: tempo
tempo = df_test[['tempo']]
tempo = min_max_scalar.fit_transform(tempo)
df_test['tempo_norm'] = tempo

# # Feature: duration_ms
# duration_ms = my_songs[['duration_ms']]
# duration_ms = min_max_scalar.fit_transform(duration_ms)
# my_songs['duration_norm'] = duration_ms

# Feature: key
key = df_test[['key']]
key = min_max_scalar.fit_transform(key)
df_test['key_norm'] = key

# Feature: time_signature
time_signature = df_test[['time_signature']]
time_signature = min_max_scalar.fit_transform(time_signature)
df_test['time_signature_norm'] = time_signature

# %%
music_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 
                  'acousticness', 'instrumentalness', 'liveness', 
                  'valence', 'tempo', 'duration_ms', 'time_signature']

songs_features = df_test[new_music_features]

# %%
X_train.head(1)
# Out:
#      danceability  energy  mode  acousticness  instrumentalness  liveness  \
# 129         0.776   0.377     1         0.567           0.00233     0.108
#
#      valence  loudness_norm  tempo_norm  key_norm  time_signature_norm
# 129    0.772       0.463343     0.08339  0.090909                  1.0

# %%
X_train.shape
# Out:
# (345, 11)

# %%
songs_features.head(1)
# Out:
#    danceability  energy  key_norm  mode  acousticness  instrumentalness  \
# 0          0.53   0.341  0.181818     1         0.836               0.0
#
#    liveness  valence  tempo_norm  time_signature_norm  loudness_norm
# 0     0.139    0.467    0.345702                  1.0       0.468112

# %%
songs_features.shape
# Out:
# (50, 11)

# %%
model2.predict(songs_features)

y_pred2 = model2.predict(songs_features)
#confusion_matrix(y_test, y_pred2)

# %%
df_test['Predicted_label'] = y_pred2

# %%
df_test['Predicted_label'].value_counts()
# Out:
# 2    42
# 4     4
# 3     4
# Name: Predicted_label, dtype: int64

# %%
https://open.spotify.com/playlist/37i9dQZF1DWZd79rJ6a7lp?si=EcNa9oIIRoi6gu_02X7yBg

# %%
df_test_2 = scraper.datascrape('spotify', '37i9dQZF1DWZd79rJ6a7lp', sp)

# %%
# Feature: loudness
loudness = df_test_2[['loudness']]
min_max_scalar = preprocessing.MinMaxScaler()

loudness = min_max_scalar.fit_transform(loudness)
df_test_2['loudness_norm'] = loudness

# Feature: tempo
tempo = df_test_2[['tempo']]
tempo = min_max_scalar.fit_transform(tempo)
df_test_2['tempo_norm'] = tempo

# # Feature: duration_ms
# duration_ms = my_songs[['duration_ms']]
# duration_ms = min_max_scalar.fit_transform(duration_ms)
# my_songs['duration_norm'] = duration_ms

# Feature: key
key = df_test_2[['key']]
key = min_max_scalar.fit_transform(key)
df_test_2['key_norm'] = key

# Feature: time_signature
time_signature = df_test_2[['time_signature']]
time_signature = min_max_scalar.fit_transform(time_signature)
df_test_2['time_signature_norm'] = time_signature

# %%
music_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 
                  'acousticness', 'instrumentalness', 'liveness', 
                  'valence', 'tempo', 'duration_ms', 'time_signature']

songs_features = df_test_2[new_music_features]

# %%
model2.predict(songs_features)

y_pred2 = model2.predict(songs_features)
#confusion_matrix(y_test, y_pred2)
df_test_2['Predicted_label'] = y_pred2

# %%
df_test_2.Predicted_label.value_counts()
# Out:
# 2    82
# 4    11
# 3     6
# 1     1
# Name: Predicted_label, dtype: int64
