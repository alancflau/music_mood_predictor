# %% [markdown]
# Data

# %%
import pandas as pd

# %%
my_songs = pd.read_csv('..//data//my_spotify_tracks.csv')

# %%
my_songs
# Out:
#                                          title  first_artist  \
# 0                                    Don't You          G5SH
# 1                                 If You Wanna       Perfume
# 2                               In My Feelings         Drake
# 3       City Lights (feat. EVO+ & Jinmenusagi)    HyperJuice
# 4                                      Save ME           BTS
# ..                                         ...           ...
# 489                               우리 둘 Runnin'         Henry
# 490                                     Bababa       4Minute
# 491  i hate u, i love u (feat. olivia o'brien)         gnash
# 492    Rockabye (feat. Sean Paul & Anne-Marie)  Clean Bandit
# 493                                   Say Yeah       AZIATIX
#
#                                      all_artists                      id  \
# 0                                       ['G5SH']  6dOtW0CfQOGr3Y5OZVsNlb
# 1                                    ['Perfume']  7Gk4yhNhOQ35ukXdmW4zWl
# 2                                      ['Drake']  0bAkKNCQfWkexHFn7fIKns
# 3           ['HyperJuice', 'EVO', 'Jinmenusagi']  41rLrTjd0p9Z1LI1jeeFHb
# 4                                        ['BTS']  0RB00aMsmBlr91i9r4Sfib
# ..                                           ...                     ...
# 489                           ['Henry', 'SOYOU']  68oQulR4Fh2Rqd4s1mXcGh
# 490                                  ['4Minute']  1nYDXIG3zYxNvVeuuPV94p
# 491                  ['gnash', "Olivia O'Brien"]  7vRriwrloYVaoAe3a9wJHe
# 492  ['Clean Bandit', 'Sean Paul', 'Anne-Marie']  5knuzwU65gJK7IF5yJsuaW
# 493                                  ['AZIATIX']  5lTimVrqEFQ7pd680wiSvq
#
#      danceability  energy  key  loudness  mode  acousticness  \
# 0           0.693   0.703    7    -5.516     1       0.00215
# 1           0.567   0.806    9    -2.040     1       0.29300
# 2           0.735   0.482    8    -9.445     1       0.00623
# 3           0.738   0.820    0    -3.181     1       0.05730
# 4           0.606   0.778    1    -4.393     1       0.02550
# ..            ...     ...  ...       ...   ...           ...
# 489         0.659   0.626    7    -6.055     1       0.50000
# 490         0.616   0.891    7    -2.398     1       0.12200
# 491         0.492   0.275    6   -13.400     0       0.68700
# 492         0.720   0.763    9    -4.068     0       0.40600
# 493         0.647   0.870    9    -5.248     0       0.09360
#
#      instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0            0.000117    0.2090    0.497  130.069       157075               4
# 1            0.195000    0.2420    0.724  149.976       163584               4
# 2            0.014400    0.4480    0.315  181.995       217933               4
# 3            0.000000    0.1610    0.549  131.025       248141               4
# 4            0.000000    0.0819    0.528  139.865       196559               4
# ..                ...       ...      ...      ...          ...             ...
# 489          0.000000    0.1650    0.394   83.944       216426               4
# 490          0.000000    0.3080    0.651  154.126       206827               4
# 491          0.000000    0.1010    0.180   92.600       251034               4
# 492          0.000000    0.1800    0.742  101.965       251088               4
# 493          0.000000    0.3690    0.663  125.012       221045               4
#
# [494 rows x 16 columns]

# %% [markdown]
# Below are descriptions of music features and its value types

# %% [markdown]
# | Music Feature| Description | Value type | Range |
# | --- | --- | --- | --- |
# | Danceability | How suitable a track is for dancing based on combination of musical elements  | float | [0.0, 1.0] |
# | Energy | Perceptual measure of intensity and activity: feel fast, loud and noisy | float | [0.0, 1.0] |
# | Key | Estimated overall key of the catch; mapped using pitch class notation | int | [0, 11] |
# | Loudness | Overall loudness of a track in decibles (dB); relative loudness | float | [-60.0, 0.0 ] |
# | Mode | Indicates the modality (major or minor) of a track | int | {0: minor, 1: minor} |
# | Acousticness | Confidence measure whether the track is acoustic | float | [0.0, 1.0] |
# | Instrumentalness | Predicts whether a track contains no vocals | float | [0.0, 1.0] |
# | Liveness | Detects presence of an audience in the recording | float | [0.0, 1.0] |
# | Valence | Musical positveness conveyed by a track (e.g happy, cheerful) | float | [0.0, 1.0] |
# | Tempo | Overall estimated tempo/speed of a track in beats per minute (BPM) | float |[0, 220] |
# | Duration ms | Duration of the song in milliseconds | int | number |
# | Time signature | Estimate how many beats are in each bar (or measure) | int | number |

# %%
my_songs['loudness'].min(), my_songs['loudness'].max()

my_songs['tempo'].min(), my_songs['tempo'].max()
# Out:
# (67.339, 207.2)

# %%
from sklearn import preprocessing
